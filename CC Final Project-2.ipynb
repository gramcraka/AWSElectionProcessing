# %% [markdown]
# Make Sure Environment contains
# Pandas
# Matplotlib
# Numpy
# Sklearn
# Collection

# %%
import pandas as pd
import numpy as np
#from pandas import Series
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot as plt
from collections import Counter
import matplotlib
# %matplotlib inline

# %% [markdown]
# Make sure to read_csv from S3 storage

# %%
data = read_csv('/users/briankruse/desktop/anes_timeseries_cdf_rawdata.txt',
                 sep='|', skipinitialspace=True,low_memory=False)
#Note this is just a raw force feeding of a delimited txt file

# %%
#https://stackoverflow.com/questions/26266362/how-to-count-the-nan-values-in-a-column-in-pandas-dataframe
#Identify Missing Values
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        #print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
         #   "There are " + str(mis_val_table_ren_columns.shape[0]) +
          #    " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
data.VCF0004.unique()
# Out:
# array([1948, 1952, 1954, 1956, 1958, 1960, 1962, 1964, 1966, 1968, 1970,
#        1972, 1974, 1976, 1978, 1980, 1982, 1984, 1986, 1988, 1990, 1992,
#        1994, 1996, 1998, 2000, 2002, 2004, 2008, 2012, 2016])

# %%
# now lets see how many have missing data for test year 2016
#https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas

data1964 = data.loc[data["VCF0004"] == 1964]
data1966 = data.loc[data["VCF0004"] == 1966]
data1968 = data.loc[data["VCF0004"] == 1968]
data1970 = data.loc[data["VCF0004"] == 1970]
data1972 = data.loc[data["VCF0004"] == 1972]
data1974 = data.loc[data["VCF0004"] == 1974]
data1976 = data.loc[data["VCF0004"] == 1976]
data1978 = data.loc[data["VCF0004"] == 1978]
data1980 = data.loc[data["VCF0004"] == 1990]
data1982 = data.loc[data["VCF0004"] == 1982]
data1984 = data.loc[data["VCF0004"] == 1984]
data1986 = data.loc[data["VCF0004"] == 1986]
data1988 = data.loc[data["VCF0004"] == 1988]
data1990 = data.loc[data["VCF0004"] == 1990]
data1992 = data.loc[data["VCF0004"] == 1992]
data1994 = data.loc[data["VCF0004"] == 1994]
data1996 = data.loc[data["VCF0004"] == 1996]
data1998 = data.loc[data["VCF0004"] == 1998]
data2000 = data.loc[data["VCF0004"] == 2000]
data2002 = data.loc[data["VCF0004"] == 2002]
data2004 = data.loc[data["VCF0004"] == 2004]
data2008 = data.loc[data["VCF0004"] == 2008]
data2012 = data.loc[data["VCF0004"] == 2012]
data2016 = data.loc[data["VCF0004"] == 2016]

# %%
missing_2016=(missing_values_table(data2016))
missing_2012=(missing_values_table(data2012))
missing_2008=(missing_values_table(data2008))
missing_2004=(missing_values_table(data2004))
missing_2002=(missing_values_table(data2002))
missing_2000=(missing_values_table(data2000))
missing_1998=(missing_values_table(data1998))
missing_1996=(missing_values_table(data1996))
missing_1994=(missing_values_table(data1994))
missing_1992=(missing_values_table(data1992))
missing_1990=(missing_values_table(data1990))
missing_1988=(missing_values_table(data1988))
missing_1986=(missing_values_table(data1986))
missing_1984=(missing_values_table(data1984))
missing_1982=(missing_values_table(data1982))
missing_1980=(missing_values_table(data1980))
missing_1978=(missing_values_table(data1978))
missing_1976=(missing_values_table(data1976))
missing_1974=(missing_values_table(data1974))
missing_1972=(missing_values_table(data1972))
missing_1970=(missing_values_table(data1970))
missing_1968=(missing_values_table(data1968))
missing_1966=(missing_values_table(data1966))
missing_1964=(missing_values_table(data1964))

# %%
missing_1964
# Out:
#           Missing Values  % of Total Values
# VCF0012             1571              100.0
# VCF0934             1571              100.0
# VCF0936             1571              100.0
# VCF0937             1571              100.0
# VCF0938             1571              100.0
# VCF0939             1571              100.0
# VCF0940             1571              100.0
# VCF0941             1571              100.0
# VCF0942             1571              100.0
# VCF0943             1571              100.0
# VCF0944             1571              100.0
# VCF0945             1571              100.0
# VCF0946             1571              100.0
# VCF0946a            1571              100.0
# VCF0947             1571              100.0
# VCF0947a            1571              100.0
# VCF0948             1571              100.0
# VCF0948a            1571              100.0
# VCF0949             1571              100.0
# VCF0949a            1571              100.0
# ...

# %%
missing_2016_shape = missing_2016.shape
missing_2012_shape = missing_2012.shape
missing_2008_shape = missing_2008.shape
missing_2004_shape = missing_2004.shape
missing_2002_shape = missing_2002.shape
missing_2000_shape = missing_2000.shape
missing_1998_shape = missing_1998.shape
missing_1996_shape = missing_1996.shape
missing_1994_shape = missing_1994.shape
missing_1992_shape = missing_1992.shape
missing_1990_shape = missing_1990.shape
missing_1988_shape = missing_1988.shape
missing_1986_shape = missing_1986.shape
missing_1984_shape = missing_1984.shape
missing_1982_shape = missing_1982.shape
missing_1980_shape = missing_1980.shape
missing_1978_shape = missing_1978.shape
missing_1976_shape = missing_1976.shape
missing_1974_shape = missing_1974.shape
missing_1972_shape = missing_1972.shape
missing_1970_shape = missing_1970.shape
missing_1968_shape = missing_1968.shape
missing_1966_shape = missing_1966.shape
missing_1964_shape = missing_1964.shape

# %%
missing_2008_shape
# Out:
# (628, 2)

# %%
missing_1964_shape
# Out:
# (726, 2)

# %%
with pd.option_context('display.max_rows', 1000, 'display.max_columns', 900):

    
    print(missing_2016)
# Out:
#           Missing Values  % of Total Values
# VCF0012             4270              100.0
# VCF0923             4270              100.0
# VCF0915             4270              100.0
# VCF0916             4270              100.0
# VCF0917             4270              100.0
# VCF0918             4270              100.0
# VCF0919             4270              100.0
# VCF0920             4270              100.0
# VCF0921             4270              100.0
# VCF0922             4270              100.0
# VCF0924             4270              100.0
# VCF0913             4270              100.0
# VCF0925             4270              100.0
# VCF0926             4270              100.0
# VCF0927             4270              100.0
# VCF0928             4270              100.0
# VCF0929             4270              100.0
# VCF0930             4270              100.0
# VCF0931             4270              100.0
# VCF0932             4270              100.0
# ...

# %%
from pandas import ExcelWriter
from pandas import ExcelFile
writer = ExcelWriter('/users/briankruse/desktop/missing_2016.xlsx')
missing_2016.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_2012.xlsx')
missing_2012.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_2008.xlsx')
missing_2008.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_2004.xlsx')
missing_2004.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_2002.xlsx')
missing_2002.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_2000.xlsx')
missing_2000.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1998.xlsx')
missing_1998.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1996.xlsx')
missing_1996.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1994.xlsx')
missing_1994.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1992.xlsx')
missing_1992.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1990.xlsx')
missing_1990.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1988.xlsx')
missing_1988.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1986.xlsx')
missing_1986.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1984.xlsx')
missing_1984.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1982.xlsx')
missing_1982.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1980.xlsx')
missing_1980.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1978.xlsx')
missing_1978.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1976.xlsx')
missing_1976.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1974.xlsx')
missing_1974.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1972.xlsx')
missing_1972.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1970.xlsx')
missing_1970.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1968.xlsx')
missing_1968.to_excel(writer,'Sheet1',index=True)
writer.save()
writer = ExcelWriter('/users/briankruse/desktop/missing_1966.xlsx')
missing_1966.to_excel(writer,'Sheet1',index=True)
writer.save()

# %% [markdown]
# Use the tabs from the spreadsheet 1984-2016
# Fill in missing values ie 999 or null with median, mean or mode

# %%
data_1984_2016 = data[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0101',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0704',
'VCF0704a',
'VCF0705',
'VCF0706',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0801',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900',
'VCF0900b',
'VCF0900c',
'VCF0901a',
'VCF0901b',
'VCF0902',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF1015',
'VCF1016',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155']]

# %%
data_1984_2016
# Out:
#        VCF0004  VCF0009y  VCF0009z  VCF0010x  VCF0010y  VCF0010z  VCF0011x  \
# 0         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 1         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 2         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 3         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 4         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 5         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 6         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 7         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 8         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 9         1948     1.000     1.000       1.0     1.000     1.000       1.0
# 10        1948     1.000     1.000       1.0     1.000     1.000       1.0
# ...

# %%
#need to drop rows < 1984
# need to drop 1986, 1990, 1994, 1998, 2002, 2006, 2010

# %%
data_gt_1984 = data_1984_2016[data_1984_2016.VCF0004 >= 1984]

# %%
data_1984_pres = data_gt_1984[(data_gt_1984.VCF0004 != 1986) &
                              (data_gt_1984.VCF0004 !=1990)&
                              (data_gt_1984.VCF0004 !=1994) &
                              (data_gt_1984.VCF0004 !=1998)&
                              (data_gt_1984.VCF0004 !=2002)]

# %%
data_1984_pres.VCF0004.unique()
# Out:
# array([1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016])

# %%
writer = ExcelWriter('/users/briankruse/desktop/data_1984_pres.xlsx')
data_1984_pres.to_excel(writer,'Sheet1',index=True)
writer.save()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data_1984_pres[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0101',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0801',
'VCF0900',
'VCF0900b',
'VCF0901a',
'VCF0902',
'VCF1015',
'VCF1016']]=scaler.fit_transform(data_1984_pres[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0101',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0801',
'VCF0900',
'VCF0900b',
'VCF0901a',
'VCF0902',
'VCF1015',
'VCF1016']])
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_1984_pres
# Out:
#         VCF0004  VCF0009y  VCF0009z  VCF0010x  VCF0010y  VCF0010z  VCF0011x  \
# 27180 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27181 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27182 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27183 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27184 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27185 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27186 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27187 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27188 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27189 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# 27190 -1.731628  0.214204 -0.000009  0.449974  0.214204 -0.000009  0.449974
# ...

# %%
data_1984_pres=pd.get_dummies(data_1984_pres, prefix=[
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0704',
'VCF0704a',
'VCF0705',
'VCF0706',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900c',
'VCF0901b',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155'], columns=[
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0704',
'VCF0704a',
'VCF0705',
'VCF0706',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900c',
'VCF0901b',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155'])

# %%
data_test = data_1984_pres.copy(deep=True)
data_train = data_1984_pres.copy(deep=True)
data_test_x = data_1984_pres.copy(deep=True)
data_train_x = data_1984_pres.copy(deep=True)

# %%
column_y =['VCF0704a_0.0', 'VCF0704a_1.0', 'VCF0704a_2.0']

# %%
data_test_x.drop(column_y, inplace=True, axis=1)
data_train_x.drop(column_y, inplace=True, axis=1)

# %%
data_test_y =data_test[['VCF0704a_1.0']]
data_train_y =data_train[['VCF0704a_1.0']]

# %%
#how do I drop the last 4270 records and keep

# %%
data_test_y = data_test_y.iloc[-4270:]
data_train_y= data_train_y.iloc[0:19751]
data_test_x = data_test_x.iloc[-4270:]
data_train_x= data_train_x.iloc[0:19751]

# %%
data_test_x.shape
# Out:
# (4270, 1318)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
#from sklearn import cross_validation
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from sklearn.metrics import mean_squared_error

# %%
pca = PCA(.95)
X_reduced = pca.fit_transform(data_train_x,data_train_y)

# %%
X_reduced
# Out:
# array([[-0.39945533,  2.61236535,  1.05988828, ..., -0.09056429,
#          0.10639374,  0.06708996],
#        [-2.34082435,  0.69703566,  0.42457497, ..., -0.45061507,
#         -0.2359004 ,  0.15212719],
#        [ 0.005669  ,  0.43588511,  2.31658841, ...,  0.07157409,
#          0.08048605,  0.17414795],
#        ...,
#        [ 0.62264059, -3.29541218, -2.87781544, ..., -0.1970686 ,
#         -0.04201149, -0.01881446],
#        [ 2.01997851, -1.44723951, -0.27670855, ...,  0.04461739,
#         -0.25219652, -0.00490948],
#        [ 0.20760661, -2.71716511,  2.32200749, ..., -0.18823769,
#         -0.12529229,  0.14544426]])

# %%
pca.n_components_
# Out:
# 289

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
# default solver is incredibly slow which is why it was changed to 'lbfgs'
logisticRegr = LogisticRegression(solver = 'lbfgs')

# %%
logisticRegr.fit(data_train_x, data_train_y)
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
logisticRegr.score(data_train_x, data_train_y)
# Out:
# 1.0
