# %% [markdown]
# Make Sure Environment contains
# Pandas
# Matplotlib
# Numpy
# Sklearn
# Collection

# %%
import pandas as pd
import numpy as np
#from pandas import Series
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot as plt
from collections import Counter
import matplotlib
# %matplotlib inline

# %% [markdown]
# Make sure to read_csv from S3 storage

# %%
data = read_csv('/users/briankruse/desktop/anes_timeseries_cdf_rawdata.txt',
                 sep='|', skipinitialspace=True,low_memory=False)
#Note this is just a raw force feeding of a delimited txt file

# %%
#https://stackoverflow.com/questions/26266362/how-to-count-the-nan-values-in-a-column-in-pandas-dataframe
#Identify Missing Values
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        #print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
         #   "There are " + str(mis_val_table_ren_columns.shape[0]) +
          #    " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
# now lets see how many have missing data for test year 2016
#https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas

data1964 = data.loc[data["VCF0004"] == 1964]
data1966 = data.loc[data["VCF0004"] == 1966]
data1968 = data.loc[data["VCF0004"] == 1968]
data1970 = data.loc[data["VCF0004"] == 1970]
data1972 = data.loc[data["VCF0004"] == 1972]
data1974 = data.loc[data["VCF0004"] == 1974]
data1976 = data.loc[data["VCF0004"] == 1976]
data1978 = data.loc[data["VCF0004"] == 1978]
data1980 = data.loc[data["VCF0004"] == 1990]
data1982 = data.loc[data["VCF0004"] == 1982]
data1984 = data.loc[data["VCF0004"] == 1984]
data1986 = data.loc[data["VCF0004"] == 1986]
data1988 = data.loc[data["VCF0004"] == 1988]
data1990 = data.loc[data["VCF0004"] == 1990]
data1992 = data.loc[data["VCF0004"] == 1992]
data1994 = data.loc[data["VCF0004"] == 1994]
data1996 = data.loc[data["VCF0004"] == 1996]
data1998 = data.loc[data["VCF0004"] == 1998]
data2000 = data.loc[data["VCF0004"] == 2000]
data2002 = data.loc[data["VCF0004"] == 2002]
data2004 = data.loc[data["VCF0004"] == 2004]
data2008 = data.loc[data["VCF0004"] == 2008]
data2012 = data.loc[data["VCF0004"] == 2012]
data2016 = data.loc[data["VCF0004"] == 2016]

# %%
missing_2016=(missing_values_table(data2016))
missing_2012=(missing_values_table(data2012))
missing_2008=(missing_values_table(data2008))
missing_2004=(missing_values_table(data2004))
missing_2002=(missing_values_table(data2002))
missing_2000=(missing_values_table(data2000))
missing_1998=(missing_values_table(data1998))
missing_1996=(missing_values_table(data1996))
missing_1994=(missing_values_table(data1994))
missing_1992=(missing_values_table(data1992))
missing_1990=(missing_values_table(data1990))
missing_1988=(missing_values_table(data1988))
missing_1986=(missing_values_table(data1986))
missing_1984=(missing_values_table(data1984))
missing_1982=(missing_values_table(data1982))
missing_1980=(missing_values_table(data1980))
missing_1978=(missing_values_table(data1978))
missing_1976=(missing_values_table(data1976))
missing_1974=(missing_values_table(data1974))
missing_1972=(missing_values_table(data1972))
missing_1970=(missing_values_table(data1970))
missing_1968=(missing_values_table(data1968))
missing_1966=(missing_values_table(data1966))
missing_1964=(missing_values_table(data1964))

# %%
data_1984_2016_x = data[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0101',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0801',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900',
'VCF0900b',
'VCF0900c',
'VCF0901a',
'VCF0901b',
'VCF0902',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF1015',
'VCF1016',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155']]

# %%
data_1984_2016_y = data[['VCF0004',
'VCF0704a',
]]

# %%
data_gt_1984_x = data_1984_2016_x[data_1984_2016_x.VCF0004 >= 1984]
data_gt_1984_y = data_1984_2016_y[data_1984_2016_y.VCF0004 >= 1984]

# %%
data_1984_pres_x = data_gt_1984_x[(data_gt_1984_x.VCF0004 != 1986) &
                              (data_gt_1984_x.VCF0004 !=1990)&
                              (data_gt_1984_x.VCF0004 !=1994) &
                              (data_gt_1984_x.VCF0004 !=1998)&
                              (data_gt_1984_x.VCF0004 !=2002)]
data_1984_pres_y = data_gt_1984_y[(data_gt_1984_y.VCF0004 != 1986) &
                              (data_gt_1984_y.VCF0004 !=1990)&
                              (data_gt_1984_y.VCF0004 !=1994) &
                              (data_gt_1984_y.VCF0004 !=1998)&
                              (data_gt_1984_y.VCF0004 !=2002)]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/fixes.py:313: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   _nan_object_mask = _nan_object_array != _nan_object_array

# %%
data_1984_pres_x[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0101',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0801',
'VCF0900',
'VCF0900b',
'VCF0901a',
'VCF0902',
'VCF1015',
'VCF1016']]=scaler.fit_transform(data_1984_pres_x[['VCF0004',
'VCF0009y',
'VCF0009z',
'VCF0010x',
'VCF0010y',
'VCF0010z',
'VCF0011x',
'VCF0011y',
'VCF0011z',
'VCF0101',
'VCF0150',
'VCF0206',
'VCF0207',
'VCF0209',
'VCF0210',
'VCF0211',
'VCF0212',
'VCF0217',
'VCF0218',
'VCF0223',
'VCF0224',
'VCF0232',
'VCF0290',
'VCF0291',
'VCF0412',
'VCF0413',
'VCF0414',
'VCF0415',
'VCF0424',
'VCF0425',
'VCF0426',
'VCF0427',
'VCF0428',
'VCF0801',
'VCF0900',
'VCF0900b',
'VCF0901a',
'VCF0902',
'VCF1015',
'VCF1016']])
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_1984_pres_x=pd.get_dummies(data_1984_pres_x, prefix=[
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900c',
'VCF0901b',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155'], columns=[
'VCF0013',
'VCF0014',
'VCF0015a',
'VCF0016',
'VCF0017',
'VCF0018a',
'VCF0102',
'VCF0103',
'VCF0104',
'VCF0105a',
'VCF0105b',
'VCF0106',
'VCF0107',
'VCF0108',
'VCF0110',
'VCF0112',
'VCF0113',
'VCF0114',
'VCF0116',
'VCF0118',
'VCF0127',
'VCF0127b',
'VCF0130',
'VCF0140',
'VCF0140a',
'VCF0143',
'VCF0146',
'VCF0147',
'VCF0301',
'VCF0302',
'VCF0303',
'VCF0305',
'VCF0310',
'VCF0346',
'VCF0349',
'VCF0358',
'VCF0359',
'VCF0360',
'VCF0361',
'VCF0370',
'VCF0371',
'VCF0372',
'VCF0373',
'VCF0450',
'VCF0451',
'VCF0475',
'VCF0481',
'VCF0487',
'VCF0493',
'VCF0501',
'VCF0503',
'VCF0504',
'VCF0605',
'VCF0606',
'VCF0624',
'VCF0649',
'VCF0656',
'VCF0702',
'VCF0703',
'VCF0707',
'VCF0708',
'VCF0709',
'VCF0710',
'VCF0713',
'VCF0714',
'VCF0717',
'VCF0718',
'VCF0719',
'VCF0720',
'VCF0721',
'VCF0723',
'VCF0723a',
'VCF0729',
'VCF0734',
'VCF0736',
'VCF0740',
'VCF0741',
'VCF0742',
'VCF0803',
'VCF0804',
'VCF0806',
'VCF0809',
'VCF0823',
'VCF0830',
'VCF0838',
'VCF0839',
'VCF0843',
'VCF0846',
'VCF0847',
'VCF0849',
'VCF0870',
'VCF0871',
'VCF0872',
'VCF0880',
'VCF0880a',
'VCF0881',
'VCF0890',
'VCF0900c',
'VCF0901b',
'VCF0903',
'VCF0904',
'VCF0905',
'VCF0991',
'VCF0992',
'VCF1004',
'VCF1005',
'VCF1011',
'VCF1012',
'VCF1013',
'VCF1014',
'VCF9009',
'VCF9013',
'VCF9016',
'VCF9017',
'VCF9018',
'VCF9022',
'VCF9023',
'VCF9030',
'VCF9030a',
'VCF9030b',
'VCF9030c',
'VCF9045',
'VCF9049',
'VCF9054',
'VCF9081',
'VCF9086',
'VCF9087',
'VCF9088',
'VCF9089',
'VCF9094',
'VCF9095',
'VCF9096',
'VCF9155'])

# %%
data_1984_pres_y=pd.get_dummies(data_1984_pres_y, prefix=[
'VCF0004','VCF0704a'], columns=[
'VCF0004','VCF0704a'])

# %%
data_1984_pres_y=data_1984_pres_y['VCF0704a_1.0']

# %%
data_test_y = data_1984_pres_y.iloc[-4270:]
data_train_y= data_1984_pres_y.iloc[0:19751]
data_test_x = data_1984_pres_x.iloc[-4270:]
data_train_x= data_1984_pres_x.iloc[0:19751]

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
#from sklearn import cross_validation
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from sklearn.metrics import mean_squared_error

# %%
pca = PCA(.95)
X_reduced = pca.fit_transform(data_train_x,data_train_y)

# %%
pca.n_components_
# Out:
# 289

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
# default solver is incredibly slow which is why it was changed to 'lbfgs'
logisticRegr = LogisticRegression(solver = 'lbfgs')

# %%
#https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8
    
from imblearn.over_sampling import SMOTE
os = SMOTE(random_state=0)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
columns = data_train_x.columns
os_data_X,os_data_y=os.fit_sample(data_train_x, data_train_y)
os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['VCF0704a_1.0'])
# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_X))
print("Number of no subscription in oversampled data",len(os_data_y[os_data_y['VCF0704a_1.0']==0]))
print("Number of subscription",len(os_data_y[os_data_y['VCF0704a_1.0']==1]))
print("Proportion of no subscription data in oversampled data is ",len(os_data_y[os_data_y['VCF0704a_1.0']==0])/len(os_data_X))
print("Proportion of subscription data in oversampled data is ",len(os_data_y[os_data_y['VCF0704a_1.0']==1])/len(os_data_X))
# Out:
# length of oversampled data is  25420
# Number of no subscription in oversampled data 12710
# Number of subscription 12710
# Proportion of no subscription data in oversampled data is  0.5
# Proportion of subscription data in oversampled data is  0.5

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
rfe = RFE(logreg, 20)
rfe = rfe.fit(os_data_X, os_data_y.values.ravel())
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
rfer=rfe.ranking_

# %%
rfer_list=np.array([rfer]).tolist()

# %%
with pd.option_context('display.max_rows', 1500, 'display.max_columns', 1):

    
    print(rfer_list)
# Out:
# [[317, 515, 556, 560, 358, 485, 191, 189, 190, 858, 81, 631, 622, 573, 610, 225, 609, 685, 246, 964, 663, 1147, 507, 506, 1164, 792, 441, 787, 41, 442, 55, 230, 365, 803, 275, 905, 598, 804, 558, 503, 65, 521, 31, 572, 946, 670, 616, 123, 1118, 170, 565, 1091, 691, 137, 619, 1267, 1234, 755, 153, 405, 244, 243, 1130, 57, 144, 104, 128, 1025, 1026, 830, 727, 56, 419, 125, 1261, 1283, 196, 822, 1282, 347, 101, 147, 513, 1246, 213, 228, 11, 303, 1245, 873, 286, 117, 176, 823, 241, 1011, 759, 917, 916, 826, 750, 914, 958, 1009, 758, 800, 919, 934, 999, 587, 724, 661, 466, 492, 152, 162, 898, 756, 163, 614, 67, 220, 1202, 328, 131, 80, 250, 194, 242, 874, 913, 446, 672, 79, 193, 488, 820, 335, 650, 786, 500, 1098, 1134, 943, 501, 327, 765, 647, 293, 203, 532, 533, 824, 356, 1131, 1162, 528, 747, 183, 723, 184, 298, 1216, 892, 437, 722, 304, 662, 297, 951, 380, 1217, 939, 422, 1117, 143, 58, 259, 516, 1195, 353, 459, 404, 1146, 290, 222, 460, 1102, 508, 682, 314, 731, 660, 435, 1079, 379, 
# ...

# %%
with pd.option_context('display.max_rows', 1500, 'display.max_columns', 2):

    
    print(os_data_X.dtypes)
# Out:
# VCF0004          float64
# VCF0009y         float64
# VCF0009z         float64
# VCF0010x         float64
# VCF0010y         float64
# VCF0010z         float64
# VCF0011x         float64
# VCF0011y         float64
# VCF0011z         float64
# VCF0101          float64
# VCF0150          float64
# VCF0206          float64
# VCF0207          float64
# VCF0209          float64
# VCF0210          float64
# VCF0211          float64
# VCF0212          float64
# VCF0217          float64
# VCF0218          float64
# VCF0223          float64
# VCF0224          float64
# VCF0232          float64
# VCF0290          float64
# VCF0291          float64
# VCF0412          float64
# VCF0413          float64
# VCF0414          float64
# VCF0415          float64
# VCF0424          float64
# VCF0425          float64
# VCF0426          float64
# VCF0427          float64
# VCF0428          float64
# VCF0801          float64
# VCF0900          float64
# VCF0900b         float64
# VCF0901a         float64
# ...

# %%
#this is the part that i filter down

# %%
data_train_x = data_train_x[[
'VCF0702_0.0',
'VCF0702_1.0',
'VCF0702_2.0',
'VCF0703_3.0',
'VCF0709_0.0',
'VCF0709_1.0',
'VCF0709_3.0',
'VCF0709_4.0',
'VCF0710_1.0',
'VCF0734_1.0',
'VCF0734_2.0',
'VCF0734_9.0',
'VCF9022_0.0']]

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
#from sklearn import cross_validation
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
# default solver is incredibly slow which is why it was changed to 'lbfgs'
logisticRegr = LogisticRegression(solver = 'lbfgs')

# %%
logisticRegr.fit(data_train_x, data_train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
logisticRegr.score(data_train_x, data_train_y)
# Out:
# 0.99356994582552782

# %%
logisticRegr.fit(data_test_x, data_test_y)
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
logisticRegr.score(data_test_x, data_test_y)
# Out:
# 1.0
